# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd 
import os 
import pathlib
# pd.set_option("display.max_rows", 100)

# import matplotlib.pylab as pylt
# pylt.rcParams['figure.dpi'] = 200
# import seaborn as sns
# import matplotlib.pyplot as plt 
# import matplotlib.dates as mdates
# %matplotlib inline

from sudulunu.helpers import pp, make_num, dumper

# %%
# iterrer = pathlib.Path('input/pro_quest')
# fillos = list(iterrer.rglob("*.csv"))

fillo = ''

data = pd.read_excel(fillo)

# %%
df = data.copy()

pp(df)

# %%
# sns.lineplot(bat, x='Month', y='moving', hue='Station')
# plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # every 3 months
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y')) 
# plt.xticks(rotation=45)
